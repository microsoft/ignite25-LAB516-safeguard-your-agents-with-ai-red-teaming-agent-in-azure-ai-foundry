# %% [markdown]
# # ⚙️ Package Installation & Version Check
#
# **IMPORTANT:** Cloud-based red teaming requires `azure-ai-projects` version `1.1.0b3` or later.
#
# In this lab, we have set it up these specific azure-ai packages.
#
# ```
# azure-ai-agents                1.2.0b3
# azure-ai-contentsafety         1.0.0
# azure-ai-evaluation            1.12.0
# azure-ai-projects              1.1.0b3
# ```
#
# Let's verify that, next.

# %%
# List curent packages
# !pip list | grep azure-ai
# Out:
# azure-ai-agents                1.2.0b3
# azure-ai-contentsafety         1.0.0
# azure-ai-evaluation            1.12.0
# azure-ai-projects              1.1.0b3
